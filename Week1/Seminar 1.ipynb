# %%
from math import exp

def f_exp(x):
    return exp(x)

def f(x):
    return x ** 2

# %%
f(-3), f(0), f(1), f(2)
# Out:
# (9, 0, 1, 4)

# %%
x0 = 3
dx_list = [1/10 ** i for i in range(11)]
for dx in dx_list:
    print(round((f(x0 + dx) - f(x0)) / dx, 3))
# Out:
# 7.0
# 6.1
# 6.01
# 6.001
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0

# %%
def g(x):
    return a * x + b

# %%
x0 = 1
dx = dx_list[-1]
a = (f(x0 + dx) - f(x0)) / dx
a
# Out:
# 2.000000165480742

# %%
b = f(x0) - a * x0
b
# Out:
# -1.000000165480742

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
# %matplotlib inline

x = np.arange(-1, 2, 0.1)

figure(figsize=(12, 8), dpi=80)
plt.plot(x, f(x), 2, 2)

plt.plot(x, g(x), 2, 2)
